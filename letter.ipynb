# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

# %%
data= pd.read_csv('letter-recognition.csv')

# %%
data
# Out:
#       letter  xbox   ybox   width   height  onpix   xbar   ybar   x2bar  \
# 0          T      2      8       3       5       1      8     13      0
# 1          I      5     12       3       7       2     10      5      5
# 2          D      4     11       6       8       6     10      6      2
# 3          N      7     11       6       6       3      5      9      4
# 4          G      2      1       3       1       1      8      6      6
# ...      ...    ...    ...     ...     ...     ...    ...    ...    ...
# 19995      D      2      2       3       3       2      7      7      7
# 19996      C      7     10       8       8       4      4      8      6
# 19997      T      6      9       6       7       5      6     11      3
# 19998      S      2      3       4       2       1      8      7      2
# 19999      A      4      9       6       6       2      9      5      3
#
#        y2bar   xybar   x2ybar  xy2bar  xedge   xedgey  yedge   yedgex
# 0           6       6      10       8       0       8       0       8
# 1           4      13       3       9       2       8       4      10
# 2           6      10       3       7       3       7       3       9
# 3           6       4       4      10       6      10       2       8
# 4           6       6       5       9       1       7       5      10
# ...       ...     ...     ...     ...     ...     ...     ...     ...
# 19995       6       6       6       4       2       8       3       7
# 19996       9      12       9      13       2       9       3       7
# 19997       7      11       9       5       2      12       2       4
# 19998       6      10       6       8       1       9       5       8
# 19999       1       8       1       8       2       7       2       8
#
# [20000 rows x 17 columns]

# %%
print("column names: ", data.columns)
# Out:
# column names:  Index(['letter', 'xbox ', 'ybox ', 'width ', 'height', 'onpix ', 'xbar ',
#        'ybar ', 'x2bar', 'y2bar ', 'xybar ', 'x2ybar', 'xy2bar', 'xedge ',
#        'xedgey', 'yedge ', 'yedgex'],
#       dtype='object')

# %%
X=data.drop(columns=['letter'])
y=data['letter']

# %%
label_encoder= LabelEncoder()
y_encoded= label_encoder.fit_transform(y)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y_encoded,test_size=0.2,random_state=42)

# %%
model= Sequential([
    Dense(128,activation='relu',input_shape=(X_train.shape[1],)),
    Dense(64,activation='relu'),
    Dense(len(label_encoder.classes_),activation='softmax')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model.fit(X_train,y_train,epochs=20,batch_size=32,validation_split=0.2)
# Out:
# Epoch 1/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3274 - loss: 2.4292 - val_accuracy: 0.6878 - val_loss: 1.1428
# Epoch 2/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6919 - loss: 1.0649 - val_accuracy: 0.7484 - val_loss: 0.9138
# Epoch 3/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7472 - loss: 0.8664 - val_accuracy: 0.7634 - val_loss: 0.8188
# Epoch 4/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7793 - loss: 0.7528 - val_accuracy: 0.7919 - val_loss: 0.7414
# Epoch 5/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7992 - loss: 0.6841 - val_accuracy: 0.8019 - val_loss: 0.6674
# Epoch 6/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8086 - loss: 0.6263 - val_accuracy: 0.8012 - val_loss: 0.6332
# Epoch 7/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8321 - loss: 0.5521 - val_accuracy: 0.8359 - val_loss: 0.5544
# Epoch 8/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8498 - loss: 0.5099 - val_accuracy: 0.8503 - val_loss: 0.5060
# Epoch 9/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8544 - loss: 0.4825 - val_accuracy: 0.8566 - val_loss: 0.4792
# Epoch 10/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8646 - loss: 0.4470 - val_accuracy: 0.8737 - val_loss: 0.4279
# Epoch 11/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8772 - loss: 0.4072 - val_accuracy: 0.8481 - val_loss: 0.4803
# Epoch 12/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8763 - loss: 0.3985 - val_accuracy: 0.8819 - val_loss: 0.3923
# Epoch 13/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8885 - loss: 0.3667 - val_accuracy: 0.8806 - val_loss: 0.3939
# Epoch 14/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8925 - loss: 0.3525 - val_accuracy: 0.8731 - val_loss: 0.4010
# Epoch 15/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8981 - loss: 0.3273 - val_accuracy: 0.8919 - val_loss: 0.3501
# Epoch 16/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9014 - loss: 0.3152 - val_accuracy: 0.8891 - val_loss: 0.3543
# Epoch 17/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9028 - loss: 0.3076 - val_accuracy: 0.8916 - val_loss: 0.3407
# Epoch 18/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9116 - loss: 0.2839 - val_accuracy: 0.8997 - val_loss: 0.3240
# Epoch 19/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9200 - loss: 0.2659 - val_accuracy: 0.8944 - val_loss: 0.3316
# Epoch 20/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9131 - loss: 0.2629 - val_accuracy: 0.8994 - val_loss: 0.3232

# %%
test_loss,test_accuracy=model.evaluate(X_test,y_test)
print("test chi accuracy:",test_accuracy)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9012 - loss: 0.3148
# test chi accuracy: 0.8999999761581421

# %%
predictions=model.predict(X_test)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
predicted_labels=label_encoder.inverse_transform(np.argmax(predictions, axis=1))

# %%
actual_labels=label_encoder.inverse_transform(y_test)

# %%
print("predicted and actual labels are")
for i in range(10):
  print("predicted:",predicted_labels[i],"actual: ",actual_labels[i])
# Out:
# predicted and actual labels are
# predicted: Z actual:  T
# predicted: R actual:  L
# predicted: A actual:  A
# predicted: E actual:  E
# predicted: Q actual:  Q
# predicted: E actual:  E
# predicted: O actual:  O
# predicted: Q actual:  Q
# predicted: G actual:  G
# predicted: O actual:  O
